# %%
# difference between print and return

# %%
def sum(a,b):
    print(a+b)
sum(2,3)
# Out:
# 5

# %%
def sum(a,b):
    print(a+b)
var = sum(2,3)
# Out:
# 5

# %%
var

# %%
print(type(var))
# Out:
# <class 'NoneType'>

# %%
def sum(a,b):
    return a+b
sum(2,3)
# Out:
# 5
