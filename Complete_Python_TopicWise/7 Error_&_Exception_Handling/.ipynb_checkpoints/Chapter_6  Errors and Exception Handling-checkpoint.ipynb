# %% [markdown]
# ***Errors*** :- It occurs when we write any statement wrong syntactically.
#
# There are three types of errors :
#
# **(1) Syntax error**----> when we write syntax wrong
# syntax error,indentation error, moddule not found error/import error,,name error,Attribute error,
#
# **(1) Runtime error** ---> also called exceptions --there is no problem in your code ..but when you run the code You get the error
#
# Index error,, value error,, key error,, type error,, zero division error,,keyboard intrupt error.
#
# **(3) Symantic Error**--> it will run code successfully ,, although our code is running and we are getting output also but
# our logic is not correct ..we will not get accurate ans..see example
#
# **Exception Handelling** :-
# 1)exception role,,2) notification,,3) error handling--> try,except,assert,else,finally,raise ,,4) termination action--> else,finally

# %% [markdown]
# ## Syntax Error

# %%
#syntax error
print('hi')'
# Out:
#   File "C:\Users\Acer\AppData\Local\Temp\ipykernel_14772\2083080024.py", line 2
#     print('hi')'
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
#indentation error
if 10>20:
print("data science")
# Out:
#   File "C:\Users\Acer\AppData\Local\Temp\ipykernel_14772\1228787243.py", line 3
#     print("data science")
#     ^
# IndentationError: expected an indented block

# %%
#module not found error
import fractions
import himanshu
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14772\2431363944.py in <module>
#       1 #module not found error
#       2 import fractions
# ----> 3 import himanshu
#
# ModuleNotFoundError: No module named 'himanshu'

# %%
#Attribute error
import math
math.himanshu()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14772\3122440235.py in <module>
#       1 #Attribute error
#       2 import math
# ----> 3 math.himanshu()
#
# AttributeError: module 'math' has no attribute 'himanshu'

# %%
#name error
a+10 #if something is not defined so it will give name error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14772\1602055368.py in <module>
#       1 #name error
# ----> 2 a+10 #if something is not defined so it will give name error
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## Runtime error

# %%
#index error
l=[1,2,3,4,5]
l[6]# there are only 4th index value available till 5..but we are asking for 6th index so it will give index error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14772\2494336942.py in <module>
#       1 #index error
#       2 l=[1,2,3,4,5]
# ----> 3 l[6]# there are only 4th index value available till 5..but we are asking for 6th index so it will give index error
#
# IndexError: list index out of range

# %%
#value error
a=int(input(' enter your number '))
# Out:
#  enter your number  A
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 #value error
# ----> 2 a=int(input(' enter your number '))
#
# ValueError: invalid literal for int() with base 10: 'A'

# %%
#value error
a=int(input(' enter a number'))
# Out:
#  enter a number'1'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14772\1340719492.py in <module>
#       1 #value error
# ----> 2 a=int(input(' enter a number'))
#
# ValueError: invalid literal for int() with base 10: "'1'"

# %%
#key error
d={1:'rishab',2:'sandeep',3:'shashank'}
d[0] #dictionary dont follow index it follow only key value
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14676\2272273015.py in <module>
#       1 #key error
#       2 d={1:'rishab',2:'sandeep',3:'shashank'}
# ----> 3 d[0] #dictionary dont follow index it follow only key value
#
# KeyError: 0

# %%
d={1:'rishab',2:'sandeep',3:'shashank'}
d[1]
# Out:
# 'rishab'

# %%
# type error
name = "indore"
grade = 10
print(name + grade)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 name = "indore"
#       3 grade = 10
# ----> 4 print(name + grade)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#Runtime error
#ZeroDivisionError
a=int(input(' enter a number '))
b=int(input(' enter a number '))
print(a/b)
# Out:
#  enter a number  4
#  enter a number  0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3 a=int(input(' enter a number '))
#       4 b=int(input(' enter a number '))
# ----> 5 print(a/b)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Exception Handling

# %%
#Runtime error
#ZeroDivisionError
a=int(input(' enter a number '))
b=int(input(' enter a number '))
print(a/b)
# Out:
#  enter a number 4
#  enter a number 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8188\4018776404.py in <module>
#       3 a=int(input(' enter a number '))
#       4 b=int(input(' enter a number '))
# ----> 5 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
#Runtime error
#ValueError
a=int(input(' enter a number '))
b=int(input(' enter a number '))
print(a/b)
# Out:
#  enter a number 9
#  enter a number o
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8188\3449553195.py in <module>
#       2 #ValueError
#       3 a=int(input(' enter a number '))
# ----> 4 b=int(input(' enter a number '))
#       5 print(a/b)
#
# ValueError: invalid literal for int() with base 10: 'o'

# %% [markdown]
# If we want to solve exception error ...so we need to guide the user

# %% [markdown]
# ### Try and Except

# %%
try:
    a=int(input('enter a number '))
    b=int(input('enter a number '))
    print(a/b)

except ZeroDivisionError:
    print('please enter other than zero')

except ValueError:
    print('please enter integer only')
# Out:
# enter a number 4
# enter a number 0
# please enter other than zero

# %%
try:
    a=int(input('enter a number '))
    b=int(input('enter a number '))
    print(a/b)

except ZeroDivisionError:
    print('please enter other than zero')

except ValueError:
    print('please enter integer only')
# Out:
# enter a number 4
# enter a number p
# please enter integer only

# %% [markdown]
# ### Finally

# %%
try:
    a=int(input('enter a number '))
    b=int(input('enter a number '))
    print(a/b)

except ZeroDivisionError:
    print('please enter other than zero')

except ValueError:
    print('please enter integer only')
    
finally:
    print('programme is completed') # finally will give output every time
# Out:
# enter a number 4
# enter a number k
# please enter integer only
# programme is completed

# %% [markdown]
# ### Else

# %%
try:
    a=int(input('enter a number '))
    b=int(input('enter a number '))
    print(a/b)

except ZeroDivisionError:
    print('please enter other than zero')

except ValueError:
    print('please enter integer only')
    
else:
    print('programme is completed') # else will give only when condition is truly satisfied
# Out:
# enter a number 4
# enter a number 2
# 2.0
# programme is completed

# %% [markdown]
# ## Assert
# is a keyword which is used in file handling which provide to make your own error

# %%
#assert----> user defined error
s=int(input('enter the age of son'))
f=int(input('enter the age of father'))
#if condition is false then we will get error
assert s<=f, "son's age can not be greater than equal to father's age"
print(s)
# Out:
# enter the age of son25
# enter the age of father20
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8188\1290809115.py in <module>
#       3 f=int(input('enter the age of father'))
#       4 #if condition is false then we will get error
# ----> 5 assert s<=f, "son's age can not be greater than equal to father's age"
#       6 print(s)
#
# AssertionError: son's age can not be greater than equal to father's age

# %%
son_age = int(input("Enter son's age: "))
father_age = int(input("Enter father's age: "))

try:
    assert son_age <= father_age, "Son's age cannot be greater than or equal to father's age"
except AssertionError as e:
    print("The assertion failed. Please enter correct ages.")
    print(e)
else:
    # This block will execute if no exception is raised
    print("The ages are valid. Proceeding with further logic.")
# Out:
# Enter son's age:  40
# Enter father's age:  20
# The assertion failed. Please enter correct ages.
# Son's age cannot be greater than or equal to father's age

# %% [markdown]
# ### Raise

# %%
try:
    a=int(input('enter a number '))
    b=int(input('enter a number '))
    if b==0:
        raise Exception('u r getting error bcz of zero')
    print(a/b)

except ValueError:
    print('please enter integer only')
    
else:
    print('program is completed')
# Out:
# enter a number 9
# enter a number 0
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8188\230112319.py in <module>
#       3     b=int(input('enter a number '))
#       4     if b==0:
# ----> 5         raise Exception('u r getting error bcz of zero')
#       6     print(a/b)
#       7
#
# Exception: u r getting error bcz of zero

# %%
try:
    a=int(input(' enter a number '))
    b=int(input(' enter a number '))
    if b==0:
        raise Exception("you are getting error because of zero")
    print(a/b)
except ValueError:
    print("please etner integer only")
else:
    print("good")
# Out:
#  enter a number  4
#  enter a number  2
# 2.0
# good

# %% [markdown]
# ### Symantic error
# **(3) Symantic Error**--> it will run code successfully ,, although our code is running and we are getting output also but
# our logic is not correct ..we will not get accurate ans..see example

# %%
a=20
b=10
print(a+b/3)  ## here we are trying to find average of two numbers but not getting accurate result
# Out:
# 23.333333333333332
