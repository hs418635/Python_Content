# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging
import os
import bs4

# %%
save_dir = "image/"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
res = requests.get("https://en.wikipedia.org/wiki/Chess")

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-enabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Chess - Wikipedia</title>
# ...

# %%
soup.select('.thumbimage')
# Out:
# [<img class="thumbimage" data-file-height="2000" data-file-width="3008" decoding="async" height="146" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/ChessStartingPosition.jpg/220px-ChessStartingPosition.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/ChessStartingPosition.jpg/330px-ChessStartingPosition.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/30/ChessStartingPosition.jpg/440px-ChessStartingPosition.jpg 2x" width="220"/>,
#  <img class="thumbimage" data-file-height="245" data-file-width="243" decoding="async" height="212" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/55/ChessCastlingMovie_en.svg/210px-ChessCastlingMovie_en.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/55/ChessCastlingMovie_en.svg/315px-ChessCastlingMovie_en.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/55/ChessCastlingMovie_en.svg/420px-ChessCastlingMovie_en.svg.png 2x" width="210"/>,
# ...

# %%
computer = soup.select('.thumbimage')[0]

# %%
computer['src']
# Out:
# '//upload.wikimedia.org/wikipedia/commons/thumb/3/30/ChessStartingPosition.jpg/220px-ChessStartingPosition.jpg'

# %% [markdown]
# <img
# src="//upload.wikimedia.org/wikipedia/commons/thumb/3/30/ChessStartingPosition.jpg/220px-ChessStartingPosition.jpg">

# %%
image_link = requests.get("https://upload.wikimedia.org/wikipedia/commons/thumb/3/30/ChessStartingPosition.jpg/220px-ChessStartingPosition.jpg")

# %%
# image_link.content

# %%
f= open('my_computer_image.jpg','wb')

# %%
f.write(image_link.content)
# Out:
# 11939

# %%
f.close()

# %%
pwd
# Out:
# 'C:\\Users\\Acer\\OneDrive\\Desktop\\M.TECH DATA SCIENCE\\1st semester\\PYTHON\\udemy lectures\\web scrapping'
