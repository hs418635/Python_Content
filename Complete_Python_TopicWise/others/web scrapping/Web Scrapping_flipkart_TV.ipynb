# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %% [markdown]
# ## How to do Scrapping

# %%
flipcart_url = "https://www.flipkart.com/search?q=" + "tv"
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=tv'

# %%
urlclient = urlopen(flipcart_url)

# %%
flipcart_page = urlclient.read()

# %%
flipcart_page #this is not is full readable formate
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.103f43.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
# now we will use beautifulsoup to see the complete text in littlebit readable formate
flipcart_html = bs(flipcart_page , 'html.parser')
# it is now somehow readable and little bit it is going to beautify

# %%
"https://www.flipkart.com" + "/sens-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-google-assistant/p/itm9340589d4f56d?pid=TVSGHY2BHWNJ7JHG&lid=LSTTVSGHY2BHWNJ7JHGV04LJU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&iid=en_NKvDOaDdNwBNeWyPrzcEdiLOzlbWEQ0s8qnNxJPrPz39Nh85HypPeI2HhYhkTwFCm67PlagLTHOYEXxoLGmq8A%3D%3D&ssid=jrm43ej6800000001679487503404&qH=c9a1fdac6e082dd8"
# Out:
# 'https://www.flipkart.com/sens-80-cm-32-inch-hd-ready-led-smart-android-tv-dolby-audio-google-assistant/p/itm9340589d4f56d?pid=TVSGHY2BHWNJ7JHG&lid=LSTTVSGHY2BHWNJ7JHGV04LJU&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_1&otracker=search&iid=en_NKvDOaDdNwBNeWyPrzcEdiLOzlbWEQ0s8qnNxJPrPz39Nh85HypPeI2HhYhkTwFCm67PlagLTHOYEXxoLGmq8A%3D%3D&ssid=jrm43ej6800000001679487503404&qH=c9a1fdac6e082dd8'

# %%
big_box = flipcart_html.find_all("div" , {"class":"_1AtVbE col-12-12"})
# it is going to return all the big box data wherever class id is going to match

# %%
# checking for how many products i am going to get big boxex
len(big_box)
# Out:
# 22

# %%
# deleting first 3 big boxes because we will get hidder details
del big_box[0:3]

# %% [markdown]
# Box div div div a
# ![image.png](attachment:image.png)

# %%
productlink = "https://www.flipkart.com" + big_box[0].div.div.div.a['href']

# %%
for i in big_box:
    print("https://www.flipkart.com" + i.div.div.div.a['href'])
#fetching one by one by one tv's by code only
# Out:
# https://www.flipkart.com/mi-5a-100-cm-40-inch-full-hd-led-smart-android-tv-dolby-audio-2022-model/p/itm6be60be56f52d?pid=TVSGD5CS4N7NWFZD&lid=LSTTVSGD5CS4N7NWFZDCMWLRV&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_H%2By0cajuVS%2BMSe2VCYPA5wDzTdqdnuy3MZdlV4R5nDMnRhiCYklmHJRxIIWLXw63c2%2F71L7M%2BrPzu6pQS%2FSKFA%3D%3D&ppt=None&ppn=None&ssid=jrl53lx5nk0000001679489184717&qH=c9a1fdac6e082dd8
# https://www.flipkart.com/lg-80-cm-32-inch-hd-ready-led-smart-webos-tv/p/itm6207e6d122567?pid=TVSFTW4CSRW8PGDQ&lid=LSTTVSFTW4CSRW8PGDQSZQIO6&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_3&otracker=search&fm=organic&iid=6cbcc077-907b-4908-bb83-8c59defc6272.TVSFTW4CSRW8PGDQ.SEARCH&ppt=None&ppn=None&ssid=jrl53lx5nk0000001679489184717&qH=c9a1fdac6e082dd8
# ...

# %%
productlink
# Out:
# 'https://www.flipkart.com/mi-5a-100-cm-40-inch-full-hd-led-smart-android-tv-dolby-audio-2022-model/p/itm6be60be56f52d?pid=TVSGD5CS4N7NWFZD&lid=LSTTVSGD5CS4N7NWFZDCMWLRV&marketplace=FLIPKART&q=tv&store=ckf%2Fczl&srno=s_1_2&otracker=search&fm=organic&iid=en_H%2By0cajuVS%2BMSe2VCYPA5wDzTdqdnuy3MZdlV4R5nDMnRhiCYklmHJRxIIWLXw63c2%2F71L7M%2BrPzu6pQS%2FSKFA%3D%3D&ppt=None&ppn=None&ssid=jrl53lx5nk0000001679489184717&qH=c9a1fdac6e082dd8'

# %%
product_req = requests.get(productlink)

# %%
product_html = bs(product_req.text, 'html.parser')

# %%
product_html
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# #scraping this comment
# ![image.png](attachment:image.png)

# %%
comment_box = product_html.find_all("div", {"class":"_16PBlm"})
comment_box
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Terrific purchase</p></div><div class="row"><div class="t-ZTKy"><div><div class="">This is a detailed review after 7 days. Please read this if you have problem or concern regarding sound/picture/brightness/sd channels/wifi connectivity/miracast. <br>PICTURE: the picture quality is really amazing. Blacks are really deep. Contrast is pretty good too. No complaints there.<br> <br> BRIGHTNESS: tv is pretty bright, by default dynamic light is on and it will make your screen dull, just turn it off. I've set it to 25. No screen galre problem.<br/><br/>SOUND: tv speakers doesn't have much bass, ide...</br></br></br></div><span class="_1BWGvX"><span>READ MORE</span></span></div></div></div><div class="row _3n8db9"><div class="row"><p class="_2sc7ZR _2V5EHH">nishant yadav</p><svg class="_2a1p_T" height="14" viewbox="0 0 12 12" w
# ...

# %%
len(comment_box) # there are 10 comments in that tv product
# Out:
# 11

# %% [markdown]
# #### let us find name to thoda 10 commentator's name

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">nishant yadav</p>]

# %%
comment_box[0].div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text
#check on the screenshot of the tv which we have pasted ..there is nishant yadav in comment
# Out:
# 'nishant yadav'

# %%
for i in comment_box:
    print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
# printing the name of the persons who posted reviws
# Out:
# nishant yadav
# sai kumar
# Deepak Rai
# Flipkart Customer
# Flipkart Customer
# SANTHOSH PILLALAMARRI
# RAJESH HEGDE
# MANISH THAKURDESAI
# Shobhit Saxena
# Ashok kumar
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14688\4276229950.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p",{"class":"_2sc7ZR _2V5EHH"})[0].text)
#       3 # printing the name of the persons who posted reviws
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %% [markdown]
# ## now fetching ratings

# %%
comment_box[0].div.div.div.div.text
# Out:
# '5'

# %%
for i in comment_box:
    print(i.div.div.div.div.text)
# Out:
# 5
# 5
# 4
# 4
# 4
# 5
# 5
# 5
# 5
# 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14688\2621339938.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Terrific purchase'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Terrific purchase
# Awesome
# Very Good
# Delightful
# Nice product
# Terrific
# Highly recommended
# Highly recommended
# Excellent
# Terrific
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14688\4044681715.py in <module>
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %% [markdown]
# ## finding actual comment

# %%
comment_box[0].div.div.find_all("div",{"class":""})[0].text
# Out:
# "This is a detailed review after 7 days. Please read this if you have problem or concern regarding sound/picture/brightness/sd channels/wifi connectivity/miracast. PICTURE: the picture quality is really amazing. Blacks are really deep. Contrast is pretty good too. No complaints there.  BRIGHTNESS: tv is pretty bright, by default dynamic light is on and it will make your screen dull, just turn it off. I've set it to 25. No screen galre problem.SOUND: tv speakers doesn't have much bass, ide...READ MORE"

# %%
for i in comment_box:
    print(i.div.div.find_all("div",{"class":""})[0].text)
# Out:
# This is a detailed review after 7 days. Please read this if you have problem or concern regarding sound/picture/brightness/sd channels/wifi connectivity/miracast. PICTURE: the picture quality is really amazing. Blacks are really deep. Contrast is pretty good too. No complaints there.  BRIGHTNESS: tv is pretty bright, by default dynamic light is on and it will make your screen dull, just turn it off. I've set it to 25. No screen galre problem.SOUND: tv speakers doesn't have much bass, ide...READ MORE
# Super and good quality full HD ,Internet also speed connecting ,it is like one smart phone .full happy and it delivered so speedREAD MORE
# ...
