# %% [markdown]
# ## How to create our own modules and packages
#
# Modules are just .py scripts that you call in another .py script
#
# Packages are a collection of modules.
#
# Or Modules are the self content block of program it contains the functions inside it .. the extension of module is .pyc
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# ![image-8.png](attachment:image-8.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# # Module

# %% [markdown]
# ## For same location
#
# To create module for same location follow the following steps:
#
# 1) open new file in idle and make a function of anything
#
# 2) save that function in your dekstop location with name you want eg_name is addition_mdoule
#
# 3) open new file again and import the function addition_module
#
# 4) again save the file with new name eg_name = call
#
# 5) now run the file in which you imported the function

# %% [markdown]
# ## Step 1st (use IDLE)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## step 2nd
# ![image.png](attachment:image.png)

# %% [markdown]
# ## step 3rd
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4th
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Dekstop par pycache name ka folden automatically banega .. jab use open karoge to module jo tumne banay hai vo show hoge
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Module for different location
#
# if 2 or more files are located in different place , so with the help of system liability we should append path

# %% [markdown]
# ## step 1

# %% [markdown]
# save this is any location
# ![image.png](attachment:image.png)

# %% [markdown]
# ## step 2nd
# save this in different location
# ![image.png](attachment:image.png)

# %% [markdown]
# ## run
#
# this error will come when you run the program
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## step 3
# now to solve this error and even if both are in different location to run them
#
# give the location of first file that contain the function inside and run this time you will get output
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Packages

# %% [markdown]
# to go to python's default locaion open idle first time,, pahle se taskbar me run nhi hona chaiye,,,,,,,,,,then go to file----open (here you are at python's default location)
# ![image-2.png](attachment:image-2.png)

# %%
## step 1st go to python's default location

# %% [markdown]
# ## create folder name game in python's default location
# ![image.png](attachment:image.png)

# %% [markdown]
# ## create module inside game folder
# ![image.png](attachment:image.png)
# Init walit file ke liye ek khali file open krke bus save kr lena hai __init__
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### test name ki file ko run karana hai ..test wali file me sab import hoge
# ![image.png](attachment:image.png)
