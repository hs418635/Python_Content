# %% [markdown]
# pypy is a repository for open-source third-party Python packages.
#
# it's similar to RubyGems in the Ruby world, PHP's Pakagist, CPAN for perl, and NPM for Node.js.

# %% [markdown]
# you can take help of google also to install particuler package
#
# eg. python package for excel ...... python package for pdf

# %% [markdown]
# ## How to create our own modules and packages
#
# Modules are just .py scripts that you call in another .py script
#
# Packages are a collection of modules.
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)

# %%
import temperature
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18004\2053062600.py in <module>
# ----> 1 import temperature
#
# ModuleNotFoundError: No module named 'temperature'
