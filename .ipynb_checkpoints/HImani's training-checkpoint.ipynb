# %%
age =int(input("type your age:"))
if age>18:
    print("you are eligible for vote")
elif age==18:
    print("documentation required")
    
else:
    print("you are not eligible for vote:")
# Out:
# type your age:18
# documentation required

# %%
f=int(input("0:g,1:1,2:2,3:3"))
if f==0:
    print("you are ground floor")
elif (f==1):
    print("1 floor")
elif f==2:
    print("you are on the 2nd floor")
elif f==3:
    print("you are top floor")
    
else:
    print("invalid input")
# Out:
# 0:g,1:1,2:2,3:32000
# invalid input

# %%
choice=int(input("1:withdrawl,2:pinchange,3:address,4:deposit"))
if choice==1:
    print("withdraw amount")
elif choice==2:
    print("pin change")
elif choice==3:
    print("your address is")
elif choice==4:
    print("deposit your money")
else:
    print("invalid input")
# Out:
# 1:withdrawl,2:pinchange,3:address,4:deposit100
# invalid input

# %%
y=int(input("enter ex"))
s=int(input("enter salary"))
if y>=5:
    print("your total bonus is:",0.05*s)
else:
    print("not eligible for bonus:")
# Out:
# enter ex6
# enter salary1000
# your total bonus is: 50.0

# %%
#take three ages from user and show oldest, youngest , and all are equal
N=int(input("age1"))
H=int(input("age2"))
h=int(input("age3"))
if N<H and N<h:
    print("N you are youngest among H and h:")
elif N>H and N>h:
    print("N you are oldest among H and h:")
elif N==H and N==h:
    print("you age is equal to H and h:")
# Out:
# age112
# age212
# age312
# you age is equal to H and h:

# %% [markdown]
# ### H/W date 24-01-2023
